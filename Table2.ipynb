# %% [markdown]
# <a href="https://colab.research.google.com/github/tsenga2/keio-senga-seminar/blob/main/Table2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
fileDownloaded = drive.CreateFile({'id':'1F3CQyQ9KWb7sU-NqN0_7H5nA-emZjD8H'})
fileDownloaded.GetContentFile('Table2.csv')

# %%
df = pd.read_csv('Table2.csv',encoding = "cp932")
df.head()
# Out:
#    日経会社コード 企業名称  株式コード      決算期  決算種別  連結基準  <【更新中止】連結剰余金計算書>（配当金）(百万円)[L033]  \
# 0        5   宝幸   9999  1985/01    10     1                               NaN
# 1        5   宝幸   9999  1986/01    10     1                               NaN
# 2        5   宝幸   9999  1987/01    10     1                               NaN
# 3        5   宝幸   9999  1988/01    10     1                               NaN
# 4        5   宝幸   9999  1988/09    10     1                               NaN
#
#    <【更新中止】連結剰余金計算書>（優先株式配当金）(百万円)[L034]  <【更新中止】連結剰余金計算書>（普通株式配当金）(百万円)[L049]  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    <【更新中止】連結剰余金計算書>（優先株式配当金）(百万円)[L050]  <貸借対照表（資産）>資産合計(百万円)[B110]  \
# 0                                   NaN                     48088.0
# 1                                   NaN                     48518.0
# 2                                   NaN                     49672.0
# 3                                   NaN                     54919.0
# 4                                   NaN                     55581.0
#
#    <損益計算書（期首からの累計期間）>親会社株主に帰属する当期純利益（連結）／当期利益（単独）［累計］(百万円)[D110]  \
# 0                                              558.0
# 1                                             1255.0
# 2                                             1666.0
# 3                                              277.0
# 4                                              151.0
#
#    <【更新中止】利益処分計算書（単独）>普通株式配当金(百万円)[L015]  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    <株主資本等変動計算書>【純資産合計／資本】剰余金の配当(百万円)[G130]  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    <株主資本等変動計算書>【純資産合計／資本】自己株式の取得(百万円)[G132]  <基本項目>配当性向［累計］(％)[A065]  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
#
#    <損益計算書（期首からの累計期間）>売上高・営業収益［累計］(百万円)[D021]  \
# 0                                   122948.0
# 1                                   126059.0
# 2                                   133723.0
# 3                                   137358.0
# 4                                    94113.0
#
#    <貸借対照表（資産）>現金・預金／現金及び現金同等物(百万円)[B022]  \
# 0                                 6545.0
# 1                                 5151.0
# 2                                 4622.0
# 3                                 5354.0
# 4                                 4179.0
#
#    <損益計算書（期首からの累計期間）>経常利益／税金等調整前当期純利益［累計］(百万円)[D066]  <基本項目>自己株式数(株)[A058]  \
# 0                                             1554.0                1000.0
# 1                                             1451.0                   NaN
# 2                                             2397.0                1000.0
# 3                                              823.0                   NaN
# 4                                              416.0                   NaN
#
#    <基本項目>自己株式数（遡及調整後）(株)[A160]  <基本項目>１株当たり配当金（各期末）(円)[A136]  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    <基本項目>１株当たり配当金（累計）(円)[A140]  <基本項目>期末発行済株式総数(株)[A057]  \
# 0                          NaN                  60000000
# 1                          NaN                  60000000
# 2                          NaN                  60000000
# 3                          NaN                  60000000
# 4                          NaN                  60000000
#
#    <基本項目>期末発行済株式総数（遡及調整後）(株)[A159]
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
df = pd.read_csv('Table2.csv',encoding = "cp932")
df = df.drop(columns={'企業名称'})
df = df.drop(columns={'株式コード'})
df = df.drop(columns={'決算種別'})
df = df.drop(columns={'連結基準'})
df = df.drop(columns={'<基本項目>自己株式数(株)[A058]'})
df = df.drop(columns={'<【更新中止】連結剰余金計算書>（配当金）(百万円)[L033]'})
df = df.drop(columns={'<【更新中止】連結剰余金計算書>（優先株式配当金）(百万円)[L034]'})
df = df.drop(columns={'<【更新中止】連結剰余金計算書>（普通株式配当金）(百万円)[L049]'})
df = df.drop(columns={'<【更新中止】連結剰余金計算書>（優先株式配当金）(百万円)[L050]'})
df = df.drop(columns={'<【更新中止】利益処分計算書（単独）>普通株式配当金(百万円)[L015]'})
df = df.drop(columns={'<株主資本等変動計算書>【純資産合計／資本】剰余金の配当(百万円)[G130]'})
df = df.drop(columns={'<基本項目>配当性向［累計］(％)[A065]'})
df = df.drop(columns={'<基本項目>自己株式数（遡及調整後）(株)[A160]'})
df = df.drop(columns={'<損益計算書（期首からの累計期間）>親会社株主に帰属する当期純利益（連結）／当期利益（単独）［累計］(百万円)[D110]'})
df = df.drop(columns={'<株主資本等変動計算書>【純資産合計／資本】自己株式の取得(百万円)[G132]'})
df = df.drop(columns={'<基本項目>１株当たり配当金（各期末）(円)[A136]'})
df = df.drop(columns={'<基本項目>期末発行済株式総数（遡及調整後）(株)[A159]'})

# %%
df = df.rename(columns={'日経会社コード':'gvkey'})
df = df.rename(columns={'決算期':'fy'})
df = df.rename(columns={'<貸借対照表（資産）>資産合計(百万円)[B110]':'assets'})
df = df.rename(columns={'<貸借対照表（資産）>現金・預金／現金及び現金同等物(百万円)[B022]':'cash'})
df = df.rename(columns={'<損益計算書（期首からの累計期間）>売上高・営業収益［累計］(百万円)[D021]':'earning'})
df = df.rename(columns={'<損益計算書（期首からの累計期間）>経常利益／税金等調整前当期純利益［累計］(百万円)[D066]':'cash flow'})
df = df.rename(columns={'<基本項目>１株当たり配当金（累計）(円)[A140]':'dividends per'})
df = df.rename(columns={'<基本項目>期末発行済株式総数(株)[A057]':'s number'})

# %%
fileDownloaded = drive.CreateFile({'id':'1cBelPYQ6tPFcK3OcACyR5x5FPp8MCugh'})
fileDownloaded.GetContentFile('Table2(consolidation).csv')

# %%
dff = pd.read_csv('Table2(consolidation).csv',encoding = "cp932")
dff = dff.rename(columns={'決算期':'fy'})
dff = dff.rename(columns={'<基本項目>自己株式数':'s hold'})
dff = dff.rename(columns={'<基本項目>１株当たり配当金（各期末）':'dividends per'})
dff['fy'] = dff['fy'].str[:4]

# %%
df['dividends'] = df['dividends per'] * df['s number']
df['total assets'] = df['dividends'] + dff['s hold'] * dff['dividends per']

# %%
df['fy'] = df['fy'].str[:4]

# %%
df.head()
# Out:
#    gvkey    fy   assets   earning    cash  cash flow  dividends per  s number  \
# 0      5  1985  48088.0  122948.0  6545.0     1554.0            NaN  60000000
# 1      5  1986  48518.0  126059.0  5151.0     1451.0            NaN  60000000
# 2      5  1987  49672.0  133723.0  4622.0     2397.0            NaN  60000000
# 3      5  1988  54919.0  137358.0  5354.0      823.0            NaN  60000000
# 4      5  1988  55581.0   94113.0  4179.0      416.0            NaN  60000000
#
#    dividends  total assets
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN

# %%
df1 = df.groupby('fy').get_group('1975')
df1 = df1.fillna(0)

# %%
df1.head()
# Out:
#        gvkey    fy     assets    earning      cash  cash flow  dividends per  \
# 9287     638  1975   248873.0   218640.0   18933.0    15064.0            0.0
# 12815    843  1975   450266.0   469158.0   52509.0    46892.0            0.0
# 16444   1038  1975   737062.0   441266.0   92171.0    47977.0            0.0
# 19069   1161  1975  2101616.0  1804051.0  281620.0    83530.0            0.0
# 19119   1162  1975  1507840.0   620347.0  248920.0     5200.0            0.0
#
#          s number  dividends  total assets
# 9287    270209000        0.0           0.0
# 12815   969583000        0.0      523494.0
# 16444   605376000        0.0           0.0
# 19069  2555581000        0.0           0.0
# 19119  1953659000        0.0           0.0

# %%
l1 = sorted(df1.loc[:,'earning'].to_list(),reverse=True)
total = l1[0]
n_1a = 0
while total <= sum(l1) * 0.5:
  n_1a += 1
  total += l1[n_1a]
print(f'n_1a={n_1a},total={total}')
n_1b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_1b={n_1b}')
print(l1[n_1a])
# Out:
# n_1a=2,total=3861767.0
# n_1b=100.0
# 672415.0

# %%
l1 = sorted(df1.loc[:,'assets'].to_list(),reverse=True)
total = l1[0]
n_2a = 0
while total <= sum(l1) * 0.5:
  n_2a += 1
  total += l1[n_2a]
print(f'n_2a={n_2a},total={total}')
n_2b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_2b={n_2b}')
# Out:
# n_2a=2,total=4883923.0
# n_2b=100.0

# %%
l1 = sorted(df1.loc[:,'cash'].to_list(),reverse=True)
total = l1[0]
n_3a = 0
while total <= sum(l1) * 0.5:
  n_3a += 1
  total += l1[n_3a]
print(f'n_3a={n_3a},total={total}')
n_3b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_3b={n_3b}')
# Out:
# n_3a=2,total=787370.0
# n_3b=100.0

# %%
l1 = sorted(df1.loc[:,'cash flow'].to_list(),reverse=True)
total = l1[0]
n_4a = 0
while total <= sum(l1) * 0.5:
  n_4a += 1
  total += l1[n_4a]
print(f'n_4a={n_4a},total={total}')
n_4b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_4b={n_4b}')
# Out:
# n_4a=2,total=210703.0
# n_4b=100.0

# %%
l1 = sorted(df1.loc[:,'dividends'].to_list(),reverse=True)
total = l1[0]
n_5a = 0
while total <= sum(l1) * 0.5:
  n_5a += 1
  total += l1[n_5a]
print(f'n_5a={n_5a},total={total}')
n_5b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_5b={n_5b}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-e692fed71f99> in <module>()
#       4 while total <= sum(l1) * 0.5:
#       5   n_5a += 1
# ----> 6   total += l1[n_5a]
#       7 print(f'n_5a={n_5a},total={total}')
#       8 n_5b = 100 * sum(l1[0:100]) / sum(l1)
#
# IndexError: list index out of range

# %%
l1 = sorted(df1.loc[:,'total assets'].to_list(),reverse=True)
total = l1[0]
n_6a = 0
while total <= sum(l1) * 0.5:
  n_6a += 1
  total += l1[n_6a]
print(f'n_6a={n_6a},total={total}')
n_6b = 100 * sum(l1[0:100]) / sum(l1)
print(f'n_6b={n_6b}')

# %%
df2 = df.groupby('fy').get_group('1995')
df2 = df2.fillna(0)

# %%
df2.head()

# %%
l2 = sorted(df2.loc[:,'earning'].to_list(),reverse=True)
total = l2[0]
n_7a = 0
while total <= sum(l2) * 0.5:
  n_7a += 1
  total += l2[n_7a]
print(f'n_7a={n_7a},total={total}')
n_7b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_7b={n_7b}')

# %%
l2 = sorted(df2.loc[:,'assets'].to_list(),reverse=True)
total = l2[0]
n_8a = 0
while total <= sum(l2) * 0.5:
  n_8a += 1
  total += l2[n_8a]
print(f'n_8a={n_8a},total={total}')
n_8b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_8b={n_8b}')

# %%
l2 = sorted(df2.loc[:,'cash'].to_list(),reverse=True)
total = l2[0]
n_9a = 0
while total <= sum(l2) * 0.5:
  n_9a += 1
  total += l2[n_9a]
print(f'n_9a={n_9a},total={total}')
n_9b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_9b={n_9b}')

# %%
l2 = sorted(df2.loc[:,'cash flow'].to_list(),reverse=True)
total = l2[0]
n_10a = 0
while total <= sum(l2) * 0.5:
  n_10a += 1
  total += l2[n_10a]
print(f'n_10a={n_10a},total={total}')
n_10b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_10b={n_10b}')

# %%
l2 = sorted(df2.loc[:,'dividends'].to_list(),reverse=True)
total = l2[0]
n_11a = 0
while total <= sum(l2) * 0.5:
  n_11a += 1
  total += l2[n_11a]
print(f'n_11a={n_11a},total={total}')
n_11b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_11b={n_11b}')

# %%
l2 = sorted(df2.loc[:,'total assets'].to_list(),reverse=True)
total = l2[0]
n_12a = 0
while total <= sum(l2) * 0.5:
  n_12a += 1
  total += l2[n_12a]
print(f'n_12a={n_12a},total={total}')
n_12b = 100 * sum(l2[0:100]) / sum(l2)
print(f'n_12b={n_12b}')

# %%
df3 = df.groupby('fy').get_group('2015')
df3 = df3.fillna(0)

# %%
df3.head()

# %%
l3 = sorted(df3.loc[:,'earning'].to_list(),reverse=True)
total = l3[0]
n_13a = 0
while total <= sum(l3) * 0.5:
  n_13a += 1
  total += l3[n_13a]
print(f'n_13a={n_13a},total={total}')
n_13b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_13b={n_13b}')

# %%
l3 = sorted(df3.loc[:,'assets'].to_list(),reverse=True)
total = l3[0]
n_14a = 0
while total <= sum(l3) * 0.5:
  n_14a += 1
  total += l3[n_14a]
print(f'n_14a={n_14a},total={total}')
n_14b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_14b={n_14b}')

# %%
l3 = sorted(df3.loc[:,'cash'].to_list(),reverse=True)
total = l3[0]
n_15a = 0
while total <= sum(l3) * 0.5:
  n_15a += 1
  total += l3[n_15a]
print(f'n_15a={n_15a},total={total}')
n_15b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_15b={n_15b}')

# %%
l3 = sorted(df3.loc[:,'cash flow'].to_list(),reverse=True)
total = l3[0]
n_16a = 0
while total <= sum(l3) * 0.5:
  n_16a += 1
  total += l3[n_16a]
print(f'n_16a={n_16a},total={total}')
n_16b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_16b={n_16b}')

# %%
l3 = sorted(df3.loc[:,'dividends'].to_list(),reverse=True)
total = l3[0]
n_17a = 0
while total <= sum(l3) * 0.5:
  n_17a += 1
  total += l3[n_17a]
print(f'n_17a={n_17a},total={total}')
n_17b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_17b={n_17b}')

# %%
l3 = sorted(df3.loc[:,'total assets'].to_list(),reverse=True)
total = l3[0]
n_18a = 0
while total <= sum(l3) * 0.5:
  n_18a += 1
  total += l3[n_18a]
print(f'n_18a={n_18a},total={total}')
n_18b = 100 * sum(l3[0:100]) / sum(l3)
print(f'n_18b={n_18b}')

# %%
list = [[n_1a,n_7a,n_13a,n_1b,n_7b,n_13b],[n_2a,n_8a,n_14a,n_2b,n_8b,n_14b],[n_3a,n_9a,n_15a,n_3b,n_9b,n_15b],
        [n_4a,n_10a,n_16a,n_4b,n_10b,n_16b],[n_5a,n_11a,n_17a,n_5b,n_11b,n_17b],[n_6a,n_12a,n_18a,n_6b,n_12b,n_18b]]
df = pd.DataFrame(list)
df.index = ['earning','assets','cash','cash flow','dividends','total assets']
df.columns=['1975','1995','2015','1975','1995','2015']
df

# %% [markdown]
# ![Table2.png](data:image/png;base64,...)
